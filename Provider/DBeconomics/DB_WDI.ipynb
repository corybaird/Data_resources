# %% [markdown]
# # DBeconomics
#
# - [python client](https://git.nomics.world/dbnomics/dbnomics-python-client/-/blob/master/index.ipynb)

# %%
from dbnomics import fetch_series, fetch_series_by_api_link

# %% [markdown]
# ## World Bank--WDI
# - [Info](https://db.nomics.world/WB)

# %%
df = fetch_series("WB", "DB", dimensions={
    "country": ["FR", "IT", "ES"],
    "indicator": ["IC.REG.COST.PC.FE.ZS.DRFN"],
})
df.head()
# Out:
#   @frequency provider_code dataset_code    dataset_name  \
# 0     annual            WB           DB  Doing Business
# 1     annual            WB           DB  Doing Business
# 2     annual            WB           DB  Doing Business
# 3     annual            WB           DB  Doing Business
# 4     annual            WB           DB  Doing Business
#
#                     series_code  \
# 0  IC.REG.COST.PC.FE.ZS.DRFN-ES
# 1  IC.REG.COST.PC.FE.ZS.DRFN-ES
# 2  IC.REG.COST.PC.FE.ZS.DRFN-ES
# 3  IC.REG.COST.PC.FE.ZS.DRFN-ES
# 4  IC.REG.COST.PC.FE.ZS.DRFN-ES
#
#                                          series_name original_period  \
# 0  Starting a business: Cost - Women (% of income...            2004
# 1  Starting a business: Cost - Women (% of income...            2005
# 2  Starting a business: Cost - Women (% of income...            2006
# 3  Starting a business: Cost - Women (% of income...            2007
# 4  Starting a business: Cost - Women (% of income...            2008
#
#       period  original_value     value                  indicator country  \
# 0 2004-01-01        91.60028  91.60028  IC.REG.COST.PC.FE.ZS.DRFN      ES
# 1 2005-01-01        91.51981  91.51981  IC.REG.COST.PC.FE.ZS.DRFN      ES
# 2 2006-01-01        91.75641  91.75641  IC.REG.COST.PC.FE.ZS.DRFN      ES
# 3 2007-01-01        91.88806  91.88806  IC.REG.COST.PC.FE.ZS.DRFN      ES
# 4 2008-01-01        92.47475  92.47475  IC.REG.COST.PC.FE.ZS.DRFN      ES
#
#                                    indicator (label) country (label)
# 0  Starting a business: Cost - Women (% of income...           Spain
# 1  Starting a business: Cost - Women (% of income...           Spain
# 2  Starting a business: Cost - Women (% of income...           Spain
# 3  Starting a business: Cost - Women (% of income...           Spain
# 4  Starting a business: Cost - Women (% of income...           Spain
