# %%
import os
import pandas as pd

from openpyxl import load_workbook
import matplotlib.pyplot as plt
import seaborn as sns

def overwrite_excel(file, new_sheet_name, df):
    book = load_workbook(file)
    writer = pd.ExcelWriter(file, engine='openpyxl') 
    writer.book = book
    writer.sheets = dict((ws.title, ws) for ws in book.worksheets)
    df.to_excel(writer, new_sheet_name)
    return writer.save()

# %% [markdown]
# ## R.2

# %%
cali_gdp_detail = pd.read_csv('Data_input/GDP_metro.csv', header=4)
cali_gdp_detail = cali_gdp_detail.replace('(D)',0)

# %%
short_names = ['Riverside','Sacramento','Salt Lake City', 'San Francisco','SLO']
name_map = {}
for long_name, short_name in zip(cali_gdp_detail.GeoName.unique(),short_names):
    name_map[long_name] = short_name
name_map
# Out:
# {'Riverside-San Bernardino-Ontario, CA (Metropolitan Statistical Area)': 'Riverside',
#  'Sacramento-Roseville-Folsom, CA (Metropolitan Statistical Area)': 'Sacramento',
#  'Salt Lake City, UT (Metropolitan Statistical Area)': 'Salt Lake City',
#  'San Francisco-Oakland-Berkeley, CA (Metropolitan Statistical Area)': 'San Francisco',
#  'San Luis Obispo-Paso Robles, CA (Metropolitan Statistical Area)': 'SLO'}

# %%
cali_gdp_detail.GeoName = cali_gdp_detail.GeoName.map(name_map)
cali_gdp_detail = cali_gdp_detail.drop(['GeoFips','LineCode'],axis=1)
cali_gdp_detail.head(4)
# Out:
#      GeoName                                        Description       2010  \
# 0  Riverside                                 All industry total  128316045
# 1  Riverside                                 Private industries  104093752
# 2  Riverside         Agriculture, forestry, fishing and hunting    1271595
# 3  Riverside      Mining, quarrying, and oil and gas extraction     260022
#
#         2011       2012       2013       2014       2015       2016  \
# 0  131792356  132669480  137405833  143289193  151135822  155513808
# 1  107602251  108933880  113477859  118877945  126037125  129244993
# 2    1475910    1137421    1098184    1478534    1523365    1541613
# 3     233995     295277     281389     318575     303927     199474
#
#         2017       2018       2019
# 0  160344031  164487230  171884061
# 1  134094895  138128908  145147475
# 2    1504196    1443111    1563179
# 3     219098     325079     319960

# %% [markdown]
# ### R.2.1 Melt

# %%
cali_wide = cali_gdp_detail.melt(id_vars=['GeoName','Description'], var_name='Date', value_name='Value')
cali_wide.Value = cali_wide.Value.astype('float')
cali_wide.head(4)
# Out:
#      GeoName                                        Description  Date  \
# 0  Riverside                                 All industry total  2010
# 1  Riverside                                 Private industries  2010
# 2  Riverside         Agriculture, forestry, fishing and hunting  2010
# 3  Riverside      Mining, quarrying, and oil and gas extraction  2010
#
#          Value
# 0  128316045.0
# 1  104093752.0
# 2    1271595.0
# 3     260022.0

# %% [markdown]
# ## R.2.2 Pivot table

# %%
cali_wide = cali_wide.pivot_table(index=['GeoName','Date'], columns='Description', values='Value')
cali_wide.head(4)
# Out:
# Description           Accommodation and food services  \
# GeoName   Date
# Riverside 2010                              3916544.0
#           2011                              4078344.0
#           2012                              4198568.0
#           2013                              4240384.0
#
# Description           Administrative and support and waste management and remediation services  \
# GeoName   Date
# Riverside 2010                                          4494654.0
#           2011                                          4832879.0
#           2012                                          4858484.0
#           2013                                          4580416.0
#
# Description           Arts, entertainment, and recreation  \
# GeoName   Date
# Riverside 2010                                   893191.0
#           2011                                   909594.0
#           2012                                   940823.0
#           2013                                  1017312.0
#
# Description           Durable goods manufacturing        Educational services  \
# GeoName   Date
# Riverside 2010                          6141786.0                   1048056.0
#           2011                          6593931.0                   1050261.0
#           2012                          6566894.0                   1053035.0
#           2013                          6731429.0                    987468.0
#
# Description           Finance and insurance  \
# GeoName   Date
# Riverside 2010                    3585599.0
#           2011                    3835199.0
#           2012                    3826077.0
#           2013                    3672090.0
#
# Description           Health care and social assistance  \
# GeoName   Date
# Riverside 2010                                9202562.0
#           2011                                9670406.0
#           2012                               10167089.0
#           2013                               10545266.0
#
# Description           Management of companies and enterprises  \
# GeoName   Date
# Riverside 2010                                       856748.0
#           2011                                       946628.0
#           2012                                       933398.0
#           2013                                       999740.0
#
# Description           Nondurable goods manufacturing  \
# GeoName   Date
# Riverside 2010                             4422189.0
#           2011                             4300521.0
#           2012                             5064268.0
#           2013                             5409844.0
#
# Description           Professional, scientific, and technical services  ...  \
# GeoName   Date                                                          ...
# Riverside 2010                                          4087931.0       ...
#           2011                                          4171702.0       ...
#           2012                                          4131884.0       ...
#           2013                                          4158078.0       ...
#
# Description         Wholesale trade    Private industries  All industry total  \
# GeoName   Date
# Riverside 2010            7337461.0           104093752.0         128316045.0
#           2011            7757935.0           107602251.0         131792356.0
#           2012            7770729.0           108933880.0         132669480.0
#           2013            8787026.0           113477859.0         137405833.0
#
# Description     Government and government enterprises  \
# GeoName   Date
# Riverside 2010                             24218263.0
#           2011                             24188794.0
#           2012                             23735599.0
#           2013                             23932470.0
#
# Description     Manufacturing and information  Natural resources and mining  \
# GeoName   Date
# Riverside 2010                     12838115.0                     1535286.0
#           2011                     13146160.0                     1707319.0
#           2012                     13838814.0                     1432697.0
#           2013                     14597609.0                     1379742.0
#
# Description     Private goods-producing industries 2/  \
# GeoName   Date
# Riverside 2010                             17296490.0
#           2011                             18429339.0
#           2012                             19141367.0
#           2013                             20163170.0
#
# Description     Private services-providing industries 3/       Trade  \
# GeoName   Date
# Riverside 2010                                86785752.0  19674082.0
#           2011                                89170354.0  20087725.0
#           2012                                89792514.0  19791768.0
#           2013                                93314366.0  21325096.0
#
# Description     Transportation and utilities
# GeoName   Date
# Riverside 2010                     8319461.0
#           2011                     8429550.0
#           2012                     9046653.0
#           2013                     8969062.0
#
# [4 rows x 34 columns]

# %%
cali_wide.columns = [x.strip() for x in cali_wide.columns]

# %%
data_types = ['Manufacturing','Finance and insurance','Construction', 'Information']

# %%
cali_wide.reset_index(inplace=True)
cali_wide.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Columns: 36 entries, GeoName to Transportation and utilities
# dtypes: float64(34), object(2)
# memory usage: 14.2+ KB

# %%
idx = pd.IndexSlice
cols = [#'Accommodation and food services',
       #'Administrative and support and waste management and remediation services',
       #'Arts, entertainment, and recreation', 'Durable goods manufacturing',
       #'Educational services', 
    #'Finance and insurance',
       #'Health care and social assistance',
       #'Management of companies and enterprises',
       'Nondurable goods manufacturing',
       #'Professional, scientific, and technical services',
       'Real estate and rental and leasing',
       #'Agriculture, forestry, fishing and hunting',
       'Arts, entertainment, recreation, accommodation, and food services',
       'Construction',
       #'Educational services, health care, and social assistance',
       'Finance, insurance, real estate, rental, and leasing', 
    'Information',
       'Manufacturing', 
    'Mining, quarrying, and oil and gas extraction',
      # 'Other services (except government and government enterprises)',
       'Professional and business services', 
    'Retail trade',
       #'Transportation and warehousing', 
    #'Utilities', 'Wholesale trade',
       'Private industries', 
    #'All industry total',
       #'Government and government enterprises',
       #'Manufacturing and information', 
    #'Natural resources and mining',
       #'Private goods-producing industries 2/',
       #'Private services-providing industries 3/', 'Trade',
       #'Transportation and utilities'
]

# %%
diff = cali_wide.set_index('Date').groupby('GeoName')[cols].last()-cali_wide.set_index('Date').groupby('GeoName')[cols].first()
pct = diff/cali_wide.set_index('Date').groupby('GeoName')[cols].first()*100
#pct.to_csv('City_industry_change_2010_2019.csv')
pct
# Out:
#                 Nondurable goods manufacturing  \
# GeoName
# Riverside                            10.764533
# SLO                                  48.857487
# Sacramento                           26.400553
# Salt Lake City                       -3.937224
# San Francisco                        16.030364
#
#                 Real estate and rental and leasing  \
# GeoName
# Riverside                                44.549690
# SLO                                      41.273251
# Sacramento                               49.686332
# Salt Lake City                           63.563048
# San Francisco                            44.156166
#
#                 Arts, entertainment, recreation, accommodation, and food services  \
# GeoName
# Riverside                                               43.608695
# SLO                                                     44.401300
# Sacramento                                              51.368720
# Salt Lake City                                          44.769005
# San Francisco                                           46.375366
#
#                 Construction  \
# GeoName
# Riverside          69.324401
# SLO                35.394991
# Sacramento         71.653252
# Salt Lake City     61.429696
# San Francisco      51.772211
#
#                 Finance, insurance, real estate, rental, and leasing  \
# GeoName
# Riverside                                               37.380569
# SLO                                                     34.337069
# Sacramento                                              35.907058
# Salt Lake City                                          47.476365
# San Francisco                                           38.676614
#
#                 Information  Manufacturing  \
# GeoName
# Riverside         41.612437      21.416575
# SLO              181.531859      40.449858
# Sacramento        27.562546       2.331704
# Salt Lake City   122.017390      -2.679458
# San Francisco    272.393701      34.703998
#
#                 Mining, quarrying, and oil and gas extraction  \
# GeoName
# Riverside                                           23.051126
# SLO                                                -55.601400
# Sacramento                                           0.146161
# Salt Lake City                                     -24.222053
# San Francisco                                      -46.638545
#
#                 Professional and business services  Retail trade  \
# GeoName
# Riverside                                32.052270     19.003505
# SLO                                      43.436683     30.822105
# Sacramento                               34.065605     27.837438
# Salt Lake City                           61.622594     40.133401
# San Francisco                            74.207414     28.037579
#
#                 Private industries
# GeoName
# Riverside                39.439181
# SLO                      30.256036
# Sacramento               36.575679
# Salt Lake City           39.078046
# San Francisco            62.420958

# %% [markdown]
# ### R.2.3 Pivot table

# %%
cali_gdp_detail.pivot(index='GeoName', columns='Description').head(2)
# Out:
#                                              2010  \
# Description       Accommodation and food services
# GeoName
# Riverside                                 3916544
# SLO                                        490909
#
#                                                                                             \
# Description       Administrative and support and waste management and remediation services
# GeoName
# Riverside                                              4494654
# SLO                                                     309337
#
#                                                        \
# Description       Arts, entertainment, and recreation
# GeoName
# Riverside                                      893191
# SLO                                             79967
#
#                                                                           \
# Description       Durable goods manufacturing       Educational services
# GeoName
# Riverside                             6141786                    1048056
# SLO                                    307991                      37400
#
#                                          \
# Description       Finance and insurance
# GeoName
# Riverside                       3585599
# SLO                              360360
#
#                                                      \
# Description       Health care and social assistance
# GeoName
# Riverside                                   9202562
# SLO                                          906926
#
#                                                            \
# Description       Management of companies and enterprises
# GeoName
# Riverside                                          856748
# SLO                                                128264
#
#                                                   \
# Description       Nondurable goods manufacturing
# GeoName
# Riverside                                4422189
# SLO                                       397851
#
#                                                                     ...  \
# Description       Professional, scientific, and technical services  ...
# GeoName                                                             ...
# Riverside                                              4087931      ...
# SLO                                                     590073      ...
#
#                             2019                              \
# Description   Private industries Addenda: All industry total
# GeoName
# Riverside              145147475      NaN          171884061
# SLO                     14712233      NaN           16660813
#
#                                                    \
# Description Government and government enterprises
# GeoName
# Riverside                                26816650
# SLO                                       1957118
#
#                                                                         \
# Description Manufacturing and information Natural resources and mining
# GeoName
# Riverside                        15961801                      1900704
# SLO                               1475604                            0
#
#                                                    \
# Description Private goods-producing industries 2/
# GeoName
# Riverside                                23634443
# SLO                                             0
#
#                                                                 \
# Description Private services-providing industries 3/     Trade
# GeoName
# Riverside                                  121531132  27735638
# SLO                                                0   1593403
#
#
# Description Transportation and utilities
# GeoName
# Riverside                       12521797
# SLO                                    0
#
# [2 rows x 350 columns]

# %%
cali_gdp_detail.melt(id_vars=['GeoName','Description']).head(2)
# Out:
#      GeoName           Description variable      value
# 0  Riverside    All industry total     2010  128316045
# 1  Riverside    Private industries     2010  104093752
